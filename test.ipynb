# %% [markdown]
# # <center> AP 2de  –  Algorithmique avec Python n°4
# ## <center> Boucles bornées « for » et non bornées  « while »
#
# ## Exercice 1
#
# #### 1) Compléter le rappel suivant :
#
# En langage Python, une **fonction** commence par le mot **def**. Quel mot doit-on utiliser pour renvoyer une valeur à la fin de la fonction ?

# %% [markdown]
# #### 2) Un prix augmente de 5 %. Par quel nombre est-il multiplié ?

# %% [markdown]
# #### 3) Compléter la fonction ci-dessous, appelée **augmentation**, qui prend un prix en argument et retourne le prix obtenu après avoir augmenté de 5 %.

# %%
def augmentation(prix):
    prix=
    return(prix)
# Out:
#   File "<input>", line 2
#     prix=
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### 4) Qu’obtient-on si on saisit augmentation(100) ? Est-ce normal ? Justifier !

# %% [markdown]
# #### 5) Quelle commande faut-il saisir pour un prix initial de 200 € ? Quelle réponse obtient-on ?

# %% [markdown]
# ## Exercice 2
#
# Chaque mois suivant, le prix augmente à nouveau de 5 %. On souhaite écrire une fonction qui prend en arguments le **prix** de départ et le nombre **n** d’augmentations successives et qui retourne le prix obtenu après ces n augmentations.  Pour cela nous allons utiliser une boucle bornée :
#
#
# **Définition :** Une boucle permet de répéter une série d’instructions.
# Une boucle est dite « bornée » quand on connait à l’avance le nombre de répétitions.
# L’instruction Python correspondant à une boucle bornée est **for __ in range(__)** :
#
#
#
# Pour bien comprendre visionner la vidéo suivante : https://www.youtube-nocookie.com/embed/07IGOcpiE7o

# %% [markdown]
# #### 1) Recopier et compléter le script ci-dessous.
#
# Chaque année, le prix est multiplié par 1,05.
#
# Pour chaque année numérotée de 0 à n-1, on va calculer le nouveau prix en multipliant par 1,05 le prix de l'année précédente.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 2) Qu’obtient-on quand on saisit aug(100,2) ?
# Est-ce normal ? Justifiez en faisant le calcul vous-même :

# %% [markdown]
# #### 3) Quelle commande saisir pour obtenir le prix après 8 augmentations, sachant que le prix initial était 150 € ?

# %% [markdown]
# #### 4) Tester plusieurs valeurs de n pour savoir à partir de quel mois le prix dépassera-t-il le double du prix initial.
# A partir de quel mois le prix initial de 150 € a-t-il doublé ? Et si on change le prix de départ ?

# %% [markdown]
# **Remarque :**
# Pour répondre à la question e) une boucle non bornée aurait été plus adaptée, car on ne connaissait pas le nombre de répétitions souhaitées.
#
# **Définition :**
# Une boucle est dite « non bornée » quand on ne connait pas à l’avance le nombre de répétitions. Le bloc d’instructions est répété tant qu’une condition est vérifiée.
# L’instruction Python correspondant à une boucle bornée est **while(_______) :**
#
# **La condition est écrite dans les parenthèses, à l’aide des symboles    <        >         !=     ou    = =**
#
# Pour bien comprendre l’instruction « while », visionner la vidéo suivante : https://www.youtube.com/watch?v=3PR51SnATus

# %%
Exercice 2 :	
Un prix vaut initialement 100 €. Il augmente chaque mois de 5 %.







	Compléter le script ci-dessus pour que la fonction mois retourne le nombre de mois à partir duquel le prix dépasse le seuil.
	Programmez et testez la commande mois(100,150)
Interpréter la réponse obtenue : ___________________________________________________
____________________________________________________________________________
	Quelle commande faut-il saisir pour obtenir le nombre de mois à partir duquel le prix a doublé ?

# %%
Exercice 3 :
Alice a un nouveau travail. On lui a promis un salaire annuel de 20 000 € pour la première année, puis une augmentation de 1 000 € par an.
Bernard touchera quant à lui 18 000 € la première année, puis son salaire augmentera de 5 % par an.
	Calculer les salaires d’Alice et Bernard la deuxième année.
_____________________________________________________________________________ _____________________________________________________________________________

	Ecrire un programme qui détermine à partir de quelle année le salaire de Bernard devient le plus avantageux.

	Question bonus : Modifier le programme pour qu’il compare non pas les salaires annuels, mais les salaires cumulés depuis le début du contrat. Au bout de combien d’année le salaire cumulé de Bernard dépasse-t-il celui d’Alice ?
# Out:
#   File "<input>", line 2
#     Exercice 3 :
#              ^
# SyntaxError: invalid syntax
